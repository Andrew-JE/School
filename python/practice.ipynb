# %%
final_grade = int(input())

if final_grade >= 95 <= 100:
    letter_grade = "A"
elif final_grade >= 90:
    letter_grade = "A-"
elif final_grade >= 86:
    letter_grade = "B+"
elif final_grade >= 83:
    letter_grade = "B"
elif final_grade >= 80:
    letter_grade = "B-"
elif final_grade >= 76:
    letter_grade = "C+"
elif final_grade >= 73:
    letter_grade = "C"
elif final_grade >= 70:
    letter_grade = "C-"
elif final_grade >= 65:
    letter_grade = "D+"
elif final_grade >= 60:
    letter_grade = "D"
else:
    letter_grade = "F"
    
print(f"The final grade is {final_grade} and the letter grade is a {letter_grade}.")
# Out:
# The final grade is 87 and the letter grade is a B+.

# %%
names = ['Essex', 'Smith', 'Jones', 'Lawrence']

for name in names:
    print(name, '|', end=' ')

print('\nPrinting in reverse')
for name in reversed(names):
    print(name, '|', end=' ')
# Out:
# Essex | Smith | Jones | Lawrence |
# Printing in reverse
# Lawrence | Jones | Smith | Essex |

# %%
'''
Program to print all 2-letter domain names.
Note that ord() and chr() convert between text and ASCII/ Unicode encodings.
ord('a') is 97. ord('b') is 98, and so on. chr(99) is 'c', etc.
'''
print('Two-letter domain names:')

letter1 = 'a'
letter2 = '?'
while letter1 <= 'z':  # Outer loop
    letter2 = 'a'
    while letter2 <= 'z':  # Inner loop
        print(f'{letter1}{letter2}.com')
        letter2 = chr(ord(letter2) + 1)
    letter1 = chr(ord(letter1) + 1)
# Out:
# Two-letter domain names:
# aa.com
# ab.com
# ac.com
# ad.com
# ae.com
# af.com
# ag.com
# ah.com
# ai.com
# aj.com
# ak.com
# al.com
# am.com
# an.com
# ao.com
# ap.com
# aq.com
# ar.com
# as.com
# at.com
# au.com
# av.com
# aw.com
# ax.com
# ay.com
# az.com
# ba.com
# bb.com
# bc.com
# bd.com
# be.com
# bf.com
# bg.com
# bh.com
# bi.com
# bj.com
# bk.com
# bl.com
# bm.com
# bn.com
# bo.com
# bp.com
# bq.com
# br.com
# bs.com
# bt.com
# bu.com
# bv.com
# bw.com
# bx.com
# by.com
# bz.com
# ca.com
# cb.com
# cc.com
# cd.com
# ce.com
# cf.com
# cg.com
# ch.com
# ci.com
# cj.com
# ck.com
# cl.com
# cm.com
# cn.com
# co.com
# cp.com
# cq.com
# cr.com
# cs.com
# ct.com
# cu.com
# cv.com
# cw.com
# cx.com
# cy.com
# cz.com
# da.com
# db.com
# dc.com
# dd.com
# de.com
# df.com
# dg.com
# dh.com
# di.com
# dj.com
# dk.com
# dl.com
# dm.com
# dn.com
# do.com
# dp.com
# dq.com
# dr.com
# ds.com
# dt.com
# du.com
# dv.com
# dw.com
# dx.com
# dy.com
# dz.com
# ea.com
# eb.com
# ec.com
# ed.com
# ee.com
# ef.com
# eg.com
# eh.com
# ei.com
# ej.com
# ek.com
# el.com
# em.com
# wx.com
# wy.com
# wz.com
# xa.com
# xb.com
# xc.com
# xd.com
# xe.com
# xf.com
# xg.com
# xh.com
# xi.com
# xj.com
# xk.com
# xl.com
# xm.com
# xn.com
# xo.com
# xp.com
# xq.com
# xr.com
# xs.com
# xt.com
# xu.com
# xv.com
# xw.com
# xx.com
# xy.com
# xz.com
# ya.com
# yb.com
# yc.com
# yd.com
# ye.com
# yf.com
# yg.com
# yh.com
# yi.com
# yj.com
# yk.com
# yl.com
# ym.com
# yn.com
# yo.com
# yp.com
# yq.com
# yr.com
# ys.com
# yt.com
# yu.com
# yv.com
# yw.com
# yx.com
# yy.com
# yz.com
# za.com
# zb.com
# zc.com
# zd.com
# ze.com
# zf.com
# zg.com
# zh.com
# zi.com
# zj.com
# zk.com
# zl.com
# zm.com
# zn.com
# zo.com
# zp.com
# zq.com
# zr.com
# zs.com
# zt.com
# zu.com
# zv.com
# zw.com
# zx.com
# zy.com
# zz.com

# %%
5.8 Challenge

num_rows = int(input())
num_cols = int(input())

num_rows = 0
num_cols = 0
for i in range(num_rows):
    print('*', end=' ')
    for j in range(num_cols):
        print('*', end=' ')
    print()

# %%
5.9 Challenges - This and following

user_input = input('Enter phone number: ')

index = 0
for character in user_input:
    print(f'Element {index} is: {character}')
    index += 1
# Out:
# Element 0 is: 2
# Element 1 is: 5
# Element 2 is: 3
# Element 3 is: -
# Element 4 is: 2
# Element 5 is: 9
# Element 6 is: 8
# Element 7 is: -
# Element 8 is: 2
# Element 9 is: 1
# Element 10 is: 5
# Element 11 is: 5

# %%
user_input = input('Enter phone number: ')
phone_number = ''

for character in user_input:
    if '0' <= character <= '9':
        phone_number += character
    elif ('a' <= character <= 'c') or ('A' <= character <= 'C'):
        phone_number += '2'
    else:
        phone_number += '?'

print(f'Numbers only: {phone_number}')
# Out:
# Numbers only: 253?298?2155

# %%
5.10

for i in range(5):
    if i < 10:
        continue
    print(i)

# %%
5.11 Loop Else

names = ['Janice', 'Clarice', 'Martin', 'Veronica', 'Jason']

num = int(input('Enter number of names to print: '))
for i in range(len(names)):
    if i == num:
        break
    print(names[i], end= ' ')
else:
    print('All names printed.')
# Out:
# Janice Clarice Martin Veronica Jason All names printed.

# %%
import edit_distance

#A few legal, acceptable Danish names
legal_names = ['Thor', 'Bjork', 'Bailey', 'Anders', 'Bent', 'Bjarne', 'Bjorn', 
    'Claus', 'Emil', 'Finn', 'Jakob', 'Karen', 'Julie', 'Johanne', 'Anna', 'Anne', 
    'Bente', 'Eva', 'Helene', 'Ida', 'Inge', 'Susanne', 'Sofie', 'Rikkie', 'Pia', 
    'Torben', 'Soren', 'Rune', 'Rasmus', 'Per', 'Michael', 'Mads', 'Hanne', 
    'Dorte'
]

user_name = input('Enter desired name:\n')
if user_name in legal_names:
    print(f'{user_name} is an acceptable Danish name. Congratulations.')
else:
    print(f'{user_name} is not acceptable.')
    for name in legal_names:
        if edit_distance.distance(name, user_name)  < 2:
            print(f'You might consider: {name},', end=' ')
            break
    else:
        print('No close matches were found.')
print('Goodbye.')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14736\671478205.py in <module>
# ----> 1 import edit_distance
#       2
#       3 #A few legal, acceptable Danish names
#       4 legal_names = ['Thor', 'Bjork', 'Bailey', 'Anders', 'Bent', 'Bjarne', 'Bjorn',
#       5     'Claus', 'Emil', 'Finn', 'Jakob', 'Karen', 'Julie', 'Johanne', 'Anna', 'Anne',
#
# ModuleNotFoundError: No module named 'edit_distance'

# %%
n_list = [1, 2, 3, 4]

sum = 0
n = 0
for i in n_list:
    if i%2 != 0:
        sum += i
        n += 1
mean = sum / n
print(mean)
# Out:
# 2.0

# %%
n_list = [1, -5, 16, 76, 127, 4]
lrgv = n_list[0]
for i in n_list:
    if i > lrgv:
        lrgv = i
print(lrgv)
# Out:
# 127

# %%
alist = ['Tom', 'Dick', 'Harry']
print(enumerate(alist))
# Out:
# <enumerate object at 0x000001A6A24A7C78>

# %%
alist = ['Tom', 'Dick', 'Harry']

for item in enumerate(alist):
    print(item, type(item))
# Out:
# (0, 'Tom') <class 'tuple'>
# (1, 'Dick') <class 'tuple'>
# (2, 'Harry') <class 'tuple'>

# %%
alist = ['Tom', 'Dick', 'Harry']

for item in enumerate(alist):
    index, value = item
    print(item, index, value)
# Out:
# (0, 'Tom') 0 Tom
# (1, 'Dick') 1 Dick
# (2, 'Harry') 2 Harry

# %%
list = [1, -5, 16, 76, 127, 4, 127]

lrgv = list[0]
for i in list:
    if i > lrgv:
        lrgv = i
print(f'The largest value is {lrgv}')

loclist = []
for index, i in enumerate(list):
    if i == lrgv:
        loclist.append(index)

for index in loclist:
    print(f'It occurs at index {index}.')
# Out:
# The largest value is 127
# It occurs at index 4.
# It occurs at index 6.

# %%
list = [1, -5, 16, 76, 127, 4, 127]

lrgv = list[0]
for i in list:
    if i >= lrgv:
        lrgv = i
print(f'The largest value is {lrgv}')

for index in loclist:
    print(f'It occurs at index {index}.')
# Out:
# The largest value is 127
# It occurs at index 4.
# It occurs at index 6.

# %%
contact_emails = {
    'Sue Reyn' : 's.reyn@email.com',
    'Mike Filt': 'mike.filt@bmail.com',
    'Nate Arty': 'narty042@nmail.com'
}

new_contact = input()
new_email = input()
contact_emails[new_contact] = new_email

name = ''
email = contact_emails[0]
for name in contact_emails:
    print(name, email)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13420\1694842237.py in <module>
#      10
#      11 name = ''
# ---> 12 email = contact_emails[0]
#      13 for name in contact_emails:
#      14     print(name, email)
#
# KeyError: 0

# %%
num_rows = int(input())
num_cols = int(input())

for i in range (num_rows):
    for j in range (num_cols):    
        print('*', end=' ')
    print()
# Out:
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
